# %%
import os
import pandas as pd

# %%
df = pd.DataFrame([])
for path, directories, files in os.walk(os.getcwd()):
     for file in files:
        if file.endswith("csv"):
            tmp_df = pd.read_csv(os.path.join(path, file), index_col=[0])
            df = pd.concat([df, tmp_df])
df = df.drop_duplicates()

# %%
df.to_excel("results.xlsx")

# %%
df
# Out:
#    AP @[IoU=0.50:0.95|area=all|maxDets=10]  \
# 0                                 0.660876
# 0                                 0.670454
# 0                                 0.647549
# 0                                 0.650670
# 0                                 0.667433
# 0                                 0.679398
#
#    AP @[IoU=0.5|area=all|maxDets=100]  \
# 0                            0.767249
# 0                            0.777946
# 0                            0.749394
# 0                            0.751303
# 0                            0.782026
# 0                            0.796639
#
#    AR @[IoU=0.50:0.95|area=all|maxDets=10]  \
# 0                                 0.711110
# 0                                 0.719273
# 0                                 0.704189
# 0                                 0.705562
# 0                                 0.717586
# 0                                 0.726450
#
#    AR @[IoU=0.50:0.95|area=all|maxDets=100]  Dataset   Model Backbone  \
# 0                                  0.738930  11class  CPNDET    DLA34
# 0                                  0.745522  11class  CPNDET    DLA34
# 0                                  0.734180  11class  CPNDET    HG104
# 0                                  0.734407  11class  CPNDET    HG104
# 0                                  0.746261  11class  CPNDET     HG52
# 0                                  0.753757  11class  CPNDET     HG52
#
#   Interpolation  Snapshot    FPS    Split DeviceType               DeviceName
# 0          None     20000  18.76  testdev        GPU  NVIDIA GeForce RTX 3090
# 0          None     20000  17.86  minival        GPU  NVIDIA GeForce RTX 3090
# 0      bilinear     30000   5.82  testdev        GPU  NVIDIA GeForce RTX 3090
# 0      bilinear     30000   5.56  minival        GPU  NVIDIA GeForce RTX 3090
# 0      bilinear     30000   8.21  testdev        GPU  NVIDIA GeForce RTX 3090
# 0      bilinear     30000   7.88  minival        GPU  NVIDIA GeForce RTX 3090
